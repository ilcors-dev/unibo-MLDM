# %% [markdown]
# # Alessio Reitano

# %%
#Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, confusion_matrix
from sklearn.model_selection import ParameterGrid
from sklearn.cluster import DBSCAN

#Variables
url1 = 'exam_superv.csv'
url2 = 'exam_unsuperv.csv'
sep = ','
random_state=42

#Directives
# %matplotlib inline
np.random.seed(random_state)

# %% [markdown]
# ### 1. Load the dataset1.csv and explore the data, showing size, structure and histograms of numeric data; show the histogram of the frequencies of the class labels, contained in the “y” column

# %%
df1 = pd.read_csv(url1, sep=sep)

# %%
print ("The dataframa are {} rows and {} columns".format(df1.shape[0],df1.shape[1]))
# Out:
# The dataframa are 1200 rows and 4 columns

# %%
df1.describe()
# Out:
#                  0            1            y            2
# count  1200.000000  1200.000000  1200.000000  1200.000000
# mean      2.391668     1.996186     0.507500     2.494236
# std       0.804770     0.507227     0.500152     0.589235
# min       0.343023     0.509424     0.000000     1.500260
# 25%       1.806657     1.809635     0.000000     1.974389
# 50%       2.744439     1.983524     1.000000     2.469778
# 75%       3.092275     2.201484     1.000000     2.995198
# max       3.529782     3.647299     1.000000     3.498523

# %%
pd.DataFrame.hist(df1, figsize=[15,15]);

# %%
plt.hist(df1.y)
plt.show()

# %% [markdown]
# ### 2. Drop the column “y” and find the best clustering scheme and hyper–parameters able to reproduce the y column (hint: before clustering you can consider dropping columns with little correlation to “y”; perhaps you should consider more than one estimator for clustering)

# %%
df = df1.drop(columns = ['y'])

# %%
df1.corr()['y']
X = df1.drop(columns = ['1'])

# %%
for i in params:
    db = DBSCAN(eps = i['eps'], min_samples = i['min_samples'])
    y_db = db.fit_predict(X)
    cluster_labels_all = np.unique(y_db)
    cluster_labels = cluster_labels_all[cluster_labels_all != -1]
    n_clusters = len(cluster_labels)
    if n_clusters >1 :
        silhouette = silhouette_score(X.to_numpy()[y_db != -1],y_db[y_db != -1])
        print ("Param EPS = "+ str(i['eps'])+"param MIN_sample ="+str(i['min_samples']))
        print ("The silhouette score is {:.2f}".format(silhouette))
        print("----------------------")
# Out:
# Param EPS = 0.05param MIN_sample =1
# The silhouette score is -0.03
# ----------------------
# Param EPS = 0.05param MIN_sample =2
# The silhouette score is 0.06
# ----------------------
# Param EPS = 0.05param MIN_sample =3
# The silhouette score is 0.01
# ----------------------
# Param EPS = 0.05param MIN_sample =4
# The silhouette score is -0.02
# ----------------------
# Param EPS = 0.05param MIN_sample =5
# The silhouette score is 0.30
# ----------------------
# Param EPS = 0.05param MIN_sample =6
# The silhouette score is 0.26
# ----------------------
# Param EPS = 0.05param MIN_sample =7
# The silhouette score is 0.33
# ----------------------
# Param EPS = 0.05param MIN_sample =8
# The silhouette score is 0.42
# ----------------------
# Param EPS = 0.05param MIN_sample =9
# The silhouette score is 0.45
# ----------------------
# Param EPS = 0.1param MIN_sample =1
# The silhouette score is -0.43
# ----------------------
# Param EPS = 0.1param MIN_sample =2
# The silhouette score is -0.33
# ----------------------
# Param EPS = 0.1param MIN_sample =3
# The silhouette score is 0.15
# ----------------------
# Param EPS = 0.1param MIN_sample =4
# The silhouette score is 0.16
# ----------------------
# Param EPS = 0.1param MIN_sample =5
# The silhouette score is 0.19
# ----------------------
# Param EPS = 0.1param MIN_sample =6
# The silhouette score is 0.26
# ----------------------
# Param EPS = 0.1param MIN_sample =7
# The silhouette score is 0.31
# ----------------------
# Param EPS = 0.1param MIN_sample =8
# The silhouette score is 0.37
# ----------------------
# Param EPS = 0.1param MIN_sample =9
# The silhouette score is 0.36
# ----------------------
# Param EPS = 0.15000000000000002param MIN_sample =1
# The silhouette score is -0.17
# ----------------------
# Param EPS = 0.15000000000000002param MIN_sample =2
# The silhouette score is 0.24
# ----------------------
# Param EPS = 0.15000000000000002param MIN_sample =3
# The silhouette score is 0.42
# ----------------------
# Param EPS = 0.15000000000000002param MIN_sample =4
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.15000000000000002param MIN_sample =5
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.15000000000000002param MIN_sample =6
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.15000000000000002param MIN_sample =7
# The silhouette score is 0.56
# ----------------------
# Param EPS = 0.15000000000000002param MIN_sample =8
# The silhouette score is 0.40
# ----------------------
# Param EPS = 0.15000000000000002param MIN_sample =9
# The silhouette score is 0.37
# ----------------------
# Param EPS = 0.2param MIN_sample =1
# The silhouette score is 0.11
# ----------------------
# Param EPS = 0.2param MIN_sample =2
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.2param MIN_sample =3
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.2param MIN_sample =4
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.2param MIN_sample =5
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.2param MIN_sample =6
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.2param MIN_sample =7
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.2param MIN_sample =8
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.2param MIN_sample =9
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.25param MIN_sample =1
# The silhouette score is 0.11
# ----------------------
# Param EPS = 0.25param MIN_sample =2
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.25param MIN_sample =3
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.25param MIN_sample =4
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.25param MIN_sample =5
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.25param MIN_sample =6
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.25param MIN_sample =7
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.25param MIN_sample =8
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.25param MIN_sample =9
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.3param MIN_sample =1
# The silhouette score is 0.33
# ----------------------
# Param EPS = 0.3param MIN_sample =2
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.3param MIN_sample =3
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.3param MIN_sample =4
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.3param MIN_sample =5
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.3param MIN_sample =6
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.3param MIN_sample =7
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.3param MIN_sample =8
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.3param MIN_sample =9
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.35000000000000003param MIN_sample =1
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.35000000000000003param MIN_sample =2
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.35000000000000003param MIN_sample =3
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.35000000000000003param MIN_sample =4
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.35000000000000003param MIN_sample =5
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.35000000000000003param MIN_sample =6
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.35000000000000003param MIN_sample =7
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.35000000000000003param MIN_sample =8
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.35000000000000003param MIN_sample =9
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.4param MIN_sample =1
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.4param MIN_sample =2
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.4param MIN_sample =3
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.4param MIN_sample =4
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.4param MIN_sample =5
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.4param MIN_sample =6
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.4param MIN_sample =7
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.4param MIN_sample =8
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.4param MIN_sample =9
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.45param MIN_sample =1
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.45param MIN_sample =2
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.45param MIN_sample =3
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.45param MIN_sample =4
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.45param MIN_sample =5
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.45param MIN_sample =6
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.45param MIN_sample =7
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.45param MIN_sample =8
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.45param MIN_sample =9
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.5param MIN_sample =1
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.5param MIN_sample =2
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.5param MIN_sample =3
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.5param MIN_sample =4
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.5param MIN_sample =5
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.5param MIN_sample =6
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.5param MIN_sample =7
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.5param MIN_sample =8
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.5param MIN_sample =9
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.55param MIN_sample =1
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.55param MIN_sample =2
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.55param MIN_sample =3
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.55param MIN_sample =4
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.55param MIN_sample =5
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.55param MIN_sample =6
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.55param MIN_sample =7
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.55param MIN_sample =8
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.55param MIN_sample =9
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.6000000000000001param MIN_sample =1
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.6000000000000001param MIN_sample =2
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.6000000000000001param MIN_sample =3
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.6000000000000001param MIN_sample =4
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.6000000000000001param MIN_sample =5
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.6000000000000001param MIN_sample =6
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.6000000000000001param MIN_sample =7
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.6000000000000001param MIN_sample =8
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.6000000000000001param MIN_sample =9
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.6500000000000001param MIN_sample =1
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.6500000000000001param MIN_sample =2
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.6500000000000001param MIN_sample =3
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.6500000000000001param MIN_sample =4
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.6500000000000001param MIN_sample =5
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.6500000000000001param MIN_sample =6
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.6500000000000001param MIN_sample =7
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.6500000000000001param MIN_sample =8
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.6500000000000001param MIN_sample =9
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.7000000000000001param MIN_sample =1
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.7000000000000001param MIN_sample =2
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.7000000000000001param MIN_sample =3
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.7000000000000001param MIN_sample =4
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.7000000000000001param MIN_sample =5
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.7000000000000001param MIN_sample =6
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.7000000000000001param MIN_sample =7
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.7000000000000001param MIN_sample =8
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.7000000000000001param MIN_sample =9
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.7500000000000001param MIN_sample =1
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.7500000000000001param MIN_sample =2
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.7500000000000001param MIN_sample =3
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.7500000000000001param MIN_sample =4
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.7500000000000001param MIN_sample =5
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.7500000000000001param MIN_sample =6
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.7500000000000001param MIN_sample =7
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.7500000000000001param MIN_sample =8
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.7500000000000001param MIN_sample =9
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.8param MIN_sample =1
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.8param MIN_sample =2
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.8param MIN_sample =3
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.8param MIN_sample =4
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.8param MIN_sample =5
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.8param MIN_sample =6
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.8param MIN_sample =7
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.8param MIN_sample =8
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.8param MIN_sample =9
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.8500000000000001param MIN_sample =1
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.8500000000000001param MIN_sample =2
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.8500000000000001param MIN_sample =3
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.8500000000000001param MIN_sample =4
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.8500000000000001param MIN_sample =5
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.8500000000000001param MIN_sample =6
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.8500000000000001param MIN_sample =7
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.8500000000000001param MIN_sample =8
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.8500000000000001param MIN_sample =9
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.9000000000000001param MIN_sample =1
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.9000000000000001param MIN_sample =2
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.9000000000000001param MIN_sample =3
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.9000000000000001param MIN_sample =4
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.9000000000000001param MIN_sample =5
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.9000000000000001param MIN_sample =6
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.9000000000000001param MIN_sample =7
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.9000000000000001param MIN_sample =8
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.9000000000000001param MIN_sample =9
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.9500000000000001param MIN_sample =1
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.9500000000000001param MIN_sample =2
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.9500000000000001param MIN_sample =3
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.9500000000000001param MIN_sample =4
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.9500000000000001param MIN_sample =5
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.9500000000000001param MIN_sample =6
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.9500000000000001param MIN_sample =7
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.9500000000000001param MIN_sample =8
# The silhouette score is 0.55
# ----------------------
# Param EPS = 0.9500000000000001param MIN_sample =9
# The silhouette score is 0.55
# ----------------------

# %% [markdown]
# ### 3.  show the difference between the original “y” column and the labels generated by the clustering, it can be expressed as “accuracy”, produce also the confusion matrix

# %%
db = DBSCAN(eps = 0.15, min_samples = 7)

# Fit and predict
db_y = db.fit_predict(X)
all_label = np.unique(db_y)
print (confusion_matrix(df1.y, db_y))
# Out:
# [[  0   0   0]
#  [ 33 558   0]
#  [  5   0 604]]
